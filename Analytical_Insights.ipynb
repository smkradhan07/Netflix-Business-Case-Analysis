# %%
# ==========================================================
# Question 6: Analytical Insights
# ==========================================================

import pandas as pd

netflix = pd.read_csv("netflix.csv")

# %%
# Release Year Concentration
year_distribution = netflix['release_year'].value_counts().sort_index()

# %%
print("Last 15 Years Growth:")
print(year_distribution.tail(15))
# Out:
# Last 15 Years Growth:
# release_year
# 2007      88
# 2008     136
# 2009     152
# 2010     194
# 2011     185
# 2012     237
# 2013     288
# 2014     352
# 2015     560
# 2016     902
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, dtype: int64

# %%
# Type Distribution Trend
print("\nMovies vs TV Shows:")
print(netflix['type'].value_counts())
# Out:
# Movies vs TV Shows:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
# Rating Insights
print("\nTop Ratings:")
print(netflix['rating'].value_counts().head(5))
# Out:
# Top Ratings:
# rating
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# Name: count, dtype: int64
